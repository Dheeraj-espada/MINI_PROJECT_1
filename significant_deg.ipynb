# %%
# Filter significant DEGs
deg = df[(df['padj'] < 0.05) & (abs(df['log2FoldChange']) > 1)]
print(deg.shape)  # Number of significant DEGs
deg.to_csv("Significant_DEGs.csv", index=False)
# Out:
# (1215, 9)

# %%
import pandas as pd

# Load the CSV file
df = pd.read_csv("DESeq2_GeneSymbols.csv")

# Display basic information
print(df.head())
print(df.info())
print(df.describe())
# Out:
#            Unnamed: 0     baseMean  log2FoldChange     lfcSE      stat  \
# 0  ENSG00000000003.15  3104.095977        0.044704  0.173195  0.258111
# 1   ENSG00000000005.6   100.642201        2.654663  0.472213  5.621749
# 2  ENSG00000000419.13  2304.327178       -0.025133  0.104952 -0.239470
# 3  ENSG00000000457.14  1568.939325       -0.164026  0.105525 -1.554379
# 4  ENSG00000000460.17   694.326636       -0.039279  0.150539 -0.260923
#
#          pvalue      padj       Ensembl_ID GeneSymbol
# 0  7.963211e-01  0.905355  ENSG00000000003     TSPAN6
# 1  1.890342e-08  0.000013  ENSG00000000005       TNMD
# 2  8.107412e-01  0.912632  ENSG00000000419       DPM1
# 3  1.200940e-01  0.363472  ENSG00000000457      SCYL3
# 4  7.941518e-01  0.904580  ENSG00000000460      FIRRM
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60660 entries, 0 to 60659
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      60660 non-null  object
#  1   baseMean        60660 non-null  float64
#  2   log2FoldChange  58048 non-null  float64
#  3   lfcSE           58048 non-null  float64
#  4   stat            58048 non-null  float64
#  5   pvalue          58048 non-null  float64
#  6   padj            34470 non-null  float64
#  7   Ensembl_ID      60660 non-null  object
#  8   GeneSymbol      44863 non-null  object
# dtypes: float64(6), object(3)
# memory usage: 4.2+ MB
# None
#             baseMean  log2FoldChange         lfcSE          stat  \
# count   60660.000000    58048.000000  58048.000000  58048.000000
# mean      922.885282        0.305511      1.182211      0.536303
# std      6573.016404        0.559406      1.879578      1.155556
# min         0.000000       -4.608646      0.043900     -9.515195
# 25%         0.196425        0.012666      0.216722      0.007441
# 50%         2.301597        0.169729      0.436609      0.302113
# 75%       101.239397        0.456830      1.114335      1.203034
# max    558876.920424        5.902970      9.213862      8.880098
#
#              pvalue          padj
# count  5.804800e+04  3.447000e+04
# mean   5.148568e-01  5.311026e-01
# std    3.543931e-01  2.923143e-01
# min    1.813717e-21  6.251882e-17
# 25%    1.616068e-01  2.784585e-01
# 50%    5.222313e-01  5.469182e-01
# 75%    8.771451e-01  7.913082e-01
# max    9.999589e-01  9.999449e-01
